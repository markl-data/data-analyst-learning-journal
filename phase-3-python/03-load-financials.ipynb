# %%
# Filter to the analysis window (2009-2022)
df_2009_2022 = df[(df["Year"] >= 2009) & (df["Year"] <= 2022)]
print(df_2009_2022.shape)   # Should be smaller than 161

# Sum revenue by year and sector
sector_yearly = df_2009_2022.groupby(["sector", "Year"]).agg(
    total_revenue=("Revenue", "sum"),
    company_count=("Company", "nunique")
)
print(sector_yearly.head(20))
print()
# Out:
# (159, 23)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[3], line 6
#       2 df_2009_2022 = df[(df["Year"] >= 2009) & (df["Year"] <= 2022)]
#       3 print(df_2009_2022.shape)   # Should be smaller than 161
#       4
#       5 # Sum revenue by year and sector
# ----> 6 sector_yearly = df_2009_2022.groupby(["sector", "Year"]).agg(
#       7     total_revenue=("Revenue", "sum"),
#       8     company_count=("Company ", "nunique")
#       9 )
#
# File c:\Users\Mark PC\anaconda3\envs\phase3\Lib\site-packages\pandas\util\_decorators.py:336, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     330 if len(args) > num_allow_args:
#     331     warnings.warn(
#     332         msg.format(arguments=_format_argument_list(allow_args)),
#     333         klass,
#     334         stacklevel=find_stack_level(),
#     335     )
# --> 336 return func(*args, **kwargs)
#
# File c:\Users\Mark PC\anaconda3\envs\phase3\Lib\site-packages\pandas\core\frame.py:10833, in DataFrame.groupby(self, by, level, as_index, sort, group_keys, observed, dropna)
#   10829
#   10830         if level is None and by is None:
#   10831             raise TypeError("You have to supply one of 'by' and 'level'")
#   10832
# > 10833         return DataFrameGroupBy(
#   10834             obj=self,
#   10835             keys=by,
#   10836             level=level,
#
# File c:\Users\Mark PC\anaconda3\envs\phase3\Lib\site-packages\pandas\core\groupby\groupby.py:1095, in GroupBy.__init__(self, obj, keys, level, grouper, exclusions, selection, as_index, sort, group_keys, observed, dropna)
#    1092 self.dropna = dropna
#    1094 if grouper is None:
# -> 1095     grouper, exclusions, obj = get_grouper(
#    1096         obj,
#    1097         keys,
#    1098         level=level,
#    1099         sort=sort,
#    1100         observed=observed,
#    1101         dropna=self.dropna,
#    1102     )
#    1104 self.observed = observed
#    1105 self.obj = obj
#
# File c:\Users\Mark PC\anaconda3\envs\phase3\Lib\site-packages\pandas\core\groupby\grouper.py:901, in get_grouper(obj, key, level, sort, observed, validate, dropna)
#     899         in_axis, level, gpr = False, gpr, None
#     900     else:
# --> 901         raise KeyError(gpr)
#     902 elif isinstance(gpr, Grouper) and gpr.key is not None:
#     903     # Add key to exclusions
#     904     exclusions.add(gpr.key)
#
# KeyError: 'sector'

# %%
# Apply the sector mapping
df["sector"] = df["Category"].map(sector_map)

# Verify it worked
print(df[["Company ", "Category", "sector"]].head(20))
print()
print(df["sector"].unique())
print()
print(df["sector"].isnull().sum())   # Should be 0 if all mapped correctly
# Out:
#    Company  Category      sector
# 0      AAPL       IT  Technology
# 1      AAPL       IT  Technology
# 2      AAPL       IT  Technology
# 3      AAPL       IT  Technology
# 4      AAPL       IT  Technology
# 5      AAPL       IT  Technology
# 6      AAPL       IT  Technology
# 7      AAPL       IT  Technology
# 8      AAPL       IT  Technology
# 9      AAPL       IT  Technology
# 10     AAPL       IT  Technology
# 11     AAPL       IT  Technology
# 12     AAPL       IT  Technology
# 13     AAPL       IT  Technology
# 14     MSFT       IT  Technology
# 15     MSFT       IT  Technology
# 16     MSFT       IT  Technology
# 17     MSFT       IT  Technology
# 18     MSFT       IT  Technology
# 19     MSFT       IT  Technology
#
# <StringArray>
# [     'Technology',         'FinTech',         'Banking',   'Manufacturing',
#          'Finance', 'Food & Beverage',     'Electronics',       'Logistics']
# Length: 8, dtype: str
#
# 0

# %%
# Look at what's actually in the Category column first
print(df["Category"].unique())
print()
# Out:
# <StringArray>
# [           'IT',       'FinTech',          'Bank', 'Manufacturing',
#        'Finance',          'FOOD',          'BANK',          'ELEC',
#           'LOGI']
# Length: 9, dtype: str

# %%
sector_map = {
    "IT": "Technology",
    "Tech": "Technology",
    "Software": "Technology",
    "FinTech": "FinTech",
    "Bank": "Banking",
    "BANK": "Banking",
    "Finance": "Finance",
    "Manufacturing": "Manufacturing",
    "ELEC": "Electronics",
    "Electronics": "Electronics",
    "LOGI": "Logistics",       # AMZN
    "FOOD": "Food & Beverage",  # MCD
}

# %%
# Which categories didn't map?
unmapped = df[df["sector"].isnull()]
print("Unmapped category values:")
print(unmapped["Category"].unique())
print()
print("Companies with unmapped rows:")
print(unmapped["Company "].unique())
print()
print(f"Total unmapped rows: {len(unmapped)}")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Mark PC\anaconda3\envs\phase3\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
# --> 168 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
# --> 197 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7668 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7676, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7676 'Could not get source, probably due dynamically evaluated source code.'
#
# KeyError: 'sector'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[5], line 2
#       1 # Which categories didn't map?
# ----> 2 unmapped = df[df["sector"].isnull()]
#       3 print("Unmapped category values:")
#       4 print(unmapped["Category"].unique())
#       5 print()
#
# File c:\Users\Mark PC\anaconda3\envs\phase3\Lib\site-packages\pandas\core\frame.py:4378, in DataFrame.__getitem__(self, key)
#    4374
#    4375         if is_single_key:
#    4376             if self.columns.nlevels > 1:
#    4377                 return self._getitem_multilevel(key)
# -> 4378             indexer = self.columns.get_loc(key)
#    4379             if is_integer(indexer):
#    4380                 indexer = [indexer]
#    4381         else:
#
# File c:\Users\Mark PC\anaconda3\envs\phase3\Lib\site-packages\pandas\core\indexes\base.py:3648, in Index.get_loc(self, key)
#    3643     if isinstance(casted_key, slice) or (
#    3644         isinstance(casted_key, abc.Iterable)
#    3645         and any(isinstance(x, slice) for x in casted_key)
#    3646     ):
#    3647         raise InvalidIndexError(key) from err
# -> 3648     raise KeyError(key) from err
#    3649 except TypeError:
#    3650     # If we have a listlike key, _check_indexing_error will raise
#    3651     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3652     #  the TypeError.
#    3653     self._check_indexing_error(key)
#
# KeyError: 'sector'

# %%
# Five inspection methods (the standard "what is this?" toolkit)
print(df.head())
print(df.shape)
print(df.dtypes)
print(df.describe())

# Companies in the data
print(df["Company "].unique())

# Year range
print(df["Year"].min(), "to", df["Year"].max())

# Rows per company (sanity check)
print(df["Company "].value_counts())
# Out:
#    Year Company  Category  Market Cap(in B USD)   Revenue  Gross Profit  \
# 0  2022     AAPL       IT               2066.94  394328.0      170782.0
# 1  2021     AAPL       IT               2913.28  365817.0      152836.0
# 2  2020     AAPL       IT               2255.97  274515.0      104956.0
# 3  2019     AAPL       IT               1304.76  260174.0       98392.0
# 4  2018     AAPL       IT                748.54  265595.0      101839.0
#
#    Net Income  Earning Per Share    EBITDA  Share Holder Equity  ...  \
# 0     99803.0               6.11  130541.0              50672.0  ...
# 1     94680.0               5.61  120233.0              63090.0  ...
# 2     57411.0               3.28   77344.0              65339.0  ...
# 3     55256.0               2.97   76477.0              90488.0  ...
# 4     59531.0               2.98   81801.0             107147.0  ...
#
#    Current Ratio  Debt/Equity Ratio       ROE      ROA      ROI  \
# 0         0.8794             2.3695  196.9589  28.2924  66.6994
# 1         1.0746             1.9768  150.0713  26.9742  54.9839
# 2         1.3636             1.7208   87.8664  17.7256  35.0054
# 3         1.5401             1.1940   61.0645  16.3230  30.3113
# 4         1.1329             1.0685   55.5601  16.2775  29.6348
#
#    Net Profit Margin  Free Cash Flow per Share  Return on Tangible Equity  \
# 0            25.3096                    1.3146                   196.9589
# 1            25.8818                    1.3261                   150.0713
# 2            20.9136                    1.0183                    87.8664
# 3            21.2381                   -0.0388                    61.0645
# 4            22.4142                    0.7414                    55.5601
#
#    Number of Employees  Inflation Rate(in US)
# 0               164000                 8.0028
# 1               154000                 4.6979
# 2               147000                 1.2336
# 3               137000                 1.8122
# 4               132000                 2.4426
#
# [5 rows x 23 columns]
# (161, 23)
# Year                                     int64
# Company                                    str
# Category                                   str
# Market Cap(in B USD)                   float64
# Revenue                                float64
# Gross Profit                           float64
# Net Income                             float64
# Earning Per Share                      float64
# EBITDA                                 float64
# Share Holder Equity                    float64
# Cash Flow from Operating               float64
# Cash Flow from Investing               float64
# Cash Flow from Financial Activities    float64
# Current Ratio                          float64
# Debt/Equity Ratio                      float64
# ROE                                    float64
# ROA                                    float64
# ROI                                    float64
# Net Profit Margin                      float64
# Free Cash Flow per Share               float64
# Return on Tangible Equity              float64
# Number of Employees                      int64
# Inflation Rate(in US)                  float64
# dtype: object
#               Year  Market Cap(in B USD)        Revenue   Gross Profit  \
# count   161.000000            160.000000     161.000000     161.000000
# mean   2015.608696            337.604312   75862.600758   37383.463124
# std       4.049960            541.102812   90786.895983   41669.093697
# min    2009.000000              0.040000    3326.445000    1174.269000
# 25%    2012.000000             41.155000   22820.400000   10396.000000
# 50%    2016.000000            113.140000   45992.040000   19561.000000
# 75%    2019.000000            357.107500   77849.000000   47722.000000
# max    2023.000000           2913.280000  513983.000000  225152.000000
#
#          Net Income  Earning Per Share         EBITDA  Share Holder Equity  \
# count    161.000000         161.000000     161.000000           161.000000
# mean   12276.607076           0.982886   20174.023974         57178.005273
# std    19417.421119           8.874504   26342.029803         54098.208311
# min   -12244.000000         -90.480000   -6860.000000         -8210.300000
# 25%      844.000000           0.340000    2310.000000         12353.000000
# 50%     4757.800000           1.790000    9958.000000         47791.000000
# 75%    14136.000000           3.240000   27765.000000         91570.700000
# max    99803.000000          14.980000  130541.000000        256144.000000
#
#        Cash Flow from Operating  Cash Flow from Investing  ...  Current Ratio  \
# count                161.000000                161.000000  ...     161.000000
# mean               20790.317839              -9581.533232  ...       2.035368
# std                27300.212516              16196.808177  ...       1.660894
# min               -39392.270000             -59611.000000  ...       0.220500
# 25%                 3502.000000             -17434.000000  ...       1.000000
# 50%                 7386.700000              -5904.000000  ...       1.341200
# 75%                31626.000000               -981.600000  ...       2.473400
# max               122151.000000              49749.000000  ...      10.617800
#
#        Debt/Equity Ratio         ROE         ROA         ROI  \
# count         161.000000  161.000000  161.000000  161.000000
# mean            0.645520   12.432402    7.780479   11.881350
# std             2.507177   44.777292    8.802462   93.384692
# min           -11.775000 -212.606900  -23.723600 -742.105200
# 25%             0.077200    5.080000    0.828200    2.757900
# 50%             0.381800   14.501600    6.641100   13.469400
# 75%             0.891400   28.189300   14.701600   20.472300
# max             9.332800  196.958900   31.154100  884.860500
#
#        Net Profit Margin  Free Cash Flow per Share  Return on Tangible Equity  \
# count         161.000000                161.000000                 161.000000
# mean           13.684964                  0.192825                  24.247542
# std            13.401767                 15.412788                 109.982817
# min           -44.696100               -121.502200                -554.174100
# 25%             4.827700                 -0.361300                   6.111800
# 50%            15.297700                  0.265600                  19.782200
# 75%            22.934500                  0.935400                  36.980600
# max            36.686300                137.328700                1197.727000
#
#        Number of Employees  Inflation Rate(in US)
# count         1.610000e+02             161.000000
# mean          1.457188e+05               2.231317
# std           2.234389e+05               1.959139
# min           5.420000e+03              -0.355500
# 25%           2.990000e+04               1.261600
# 50%           9.600000e+04               1.812200
# 75%           1.470000e+05               2.442600
# max           1.608000e+06               8.002800
#
# [8 rows x 21 columns]
# <StringArray>
# [ 'AAPL',  'MSFT',  'GOOG',  'PYPL',   'AIG',   'PCG', 'SHLDQ',   'MCD',
#    'BCS',  'NVDA',  'INTC',  'AMZN']
# Length: 12, dtype: str
# 2009 to 2023
# Company
# MSFT     15
# NVDA     15
# AAPL     14
# GOOG     14
# AIG      14
# PCG      14
# MCD      14
# BCS      14
# INTC     14
# AMZN     14
# SHLDQ    10
# PYPL      9
# Name: count, dtype: int64

# %%
df.head()
# Out:
#    Year Company  Category  Market Cap(in B USD)   Revenue  Gross Profit  \
# 0  2022     AAPL       IT               2066.94  394328.0      170782.0
# 1  2021     AAPL       IT               2913.28  365817.0      152836.0
# 2  2020     AAPL       IT               2255.97  274515.0      104956.0
# 3  2019     AAPL       IT               1304.76  260174.0       98392.0
# 4  2018     AAPL       IT                748.54  265595.0      101839.0
#
#    Net Income  Earning Per Share    EBITDA  Share Holder Equity  ...  \
# 0     99803.0               6.11  130541.0              50672.0  ...
# 1     94680.0               5.61  120233.0              63090.0  ...
# 2     57411.0               3.28   77344.0              65339.0  ...
# 3     55256.0               2.97   76477.0              90488.0  ...
# 4     59531.0               2.98   81801.0             107147.0  ...
#
#    Current Ratio  Debt/Equity Ratio       ROE      ROA      ROI  \
# 0         0.8794             2.3695  196.9589  28.2924  66.6994
# 1         1.0746             1.9768  150.0713  26.9742  54.9839
# 2         1.3636             1.7208   87.8664  17.7256  35.0054
# 3         1.5401             1.1940   61.0645  16.3230  30.3113
# 4         1.1329             1.0685   55.5601  16.2775  29.6348
#
#    Net Profit Margin  Free Cash Flow per Share  Return on Tangible Equity  \
# 0            25.3096                    1.3146                   196.9589
# 1            25.8818                    1.3261                   150.0713
# 2            20.9136                    1.0183                    87.8664
# 3            21.2381                   -0.0388                    61.0645
# 4            22.4142                    0.7414                    55.5601
#
#    Number of Employees  Inflation Rate(in US)
# 0               164000                 8.0028
# 1               154000                 4.6979
# 2               147000                 1.2336
# 3               137000                 1.8122
# 4               132000                 2.4426
#
# [5 rows x 23 columns]

# %%
import pandas as pd
from pathlib import Path
   
SCRIPT_DIR = Path().resolve()   # notebook version
df = pd.read_csv(SCRIPT_DIR / "data" / "Financial Statements.csv")
df.shape
# Out:
# (161, 23)
